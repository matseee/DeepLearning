# %%
import sys, numpy as np
from keras.datasets import mnist

(xTrain, yTrain), (xTest, yTest) = mnist.load_data()

images, labels = (xTrain[0:1000].reshape(1000, 28*28) / 255, yTrain[0:1000])

oneHotLabels = np.zeros((len(labels), 10))

for i,l in enumerate(labels):
    oneHotLabels[i][l] = 1

labels = oneHotLabels

testImages = xTest.reshape(len(xTest), 28*28) / 255
testLabels = np.zeros((len(yTest), 10))

for i,l in enumerate(yTest):
    testLabels[i][l] = 1

np.random.seed(1)

relu = lambda x: (x>=0) * x
relu2Deriv = lambda x: x>=0

alpha = 0.005
iterations = 350
hiddenSize = 40
pixelsPerImage = 784
numLabels = 10

weights1 = 0.2 * np.random.random((pixelsPerImage, hiddenSize)) - 0.1
weights2 = 0.2 * np.random.random((hiddenSize, numLabels)) - 0.1

for iter in range(iterations):
    error, correctCount = (0.0, 0)

    for i in range(len(images)):
        layer0 = images[i:i+1]
        layer1 = relu(np.dot(layer0, weights1))
        layer2 = np.dot(layer1, weights2)

        error += np.sum((layer2 - labels[i:i+1]) ** 2)
        correctCount += int(np.argmax(layer2) == np.argmax(labels[i:i+1]))

        delta2 = layer2 - labels[i:i+1]
        delta1 = delta2.dot(weights2.T) * relu2Deriv(layer1)

        weights2 -= alpha * layer1.T.dot(delta2)
        weights1 -= alpha * layer0.T.dot(delta1)
    
    sys.stdout.write("\r Iter:" + str(iter) + " Error:" + str(error/float(len(images)))[0:5] + " Correct:" + str(correctCount/float(len(images))))

# %%
# WITH RIGHT RELU FUNCTION => ITS WRONG ABOVE AND IN THE BOOK
import sys, numpy as np
from keras.datasets import mnist

(xTrain, yTrain), (xTest, yTest) = mnist.load_data()

images, labels = (xTrain[0:1000].reshape(1000, 28*28) / 255, yTrain[0:1000])

oneHotLabels = np.zeros((len(labels), 10))

for i,l in enumerate(labels):
    oneHotLabels[i][l] = 1

labels = oneHotLabels

testImages = xTest.reshape(len(xTest), 28*28) / 255
testLabels = np.zeros((len(yTest), 10))

for i,l in enumerate(yTest):
    testLabels[i][l] = 1

np.random.seed(1)

relu = lambda x: (x>0) * x
relu2Deriv = lambda x: x>0

alpha = 0.005
iterations = 350
hiddenSize = 40
pixelsPerImage = 784
numLabels = 10

weights1 = 0.2 * np.random.random((pixelsPerImage, hiddenSize)) - 0.1
weights2 = 0.2 * np.random.random((hiddenSize, numLabels)) - 0.1

for iter in range(iterations):
    error, correctCount = (0.0, 0)

    for i in range(len(images)):
        layer0 = images[i:i+1]
        layer1 = relu(np.dot(layer0, weights1))
        layer2 = np.dot(layer1, weights2)

        error += np.sum((layer2 - labels[i:i+1]) ** 2)
        correctCount += int(np.argmax(layer2) == np.argmax(labels[i:i+1]))

        delta2 = layer2 - labels[i:i+1]
        delta1 = delta2.dot(weights2.T) * relu2Deriv(layer1)

        weights2 -= alpha * layer1.T.dot(delta2)
        weights1 -= alpha * layer0.T.dot(delta1)
    
    sys.stdout.write("\r Iter:" + str(iter) + " Error:" + str(error/float(len(images)))[0:5] + " Correct:" + str(correctCount/float(len(images))))
