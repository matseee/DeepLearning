# %%
import sys, numpy as np
from keras.datasets import mnist

(xTrain, yTrain), (xTest, yTest) = mnist.load_data()

images, labels = (xTrain[0:1000].reshape(1000, 28*28) / 255, yTrain[0:1000])

oneHotLabels = np.zeros((len(labels), 10))

for i,l in enumerate(labels):
    oneHotLabels[i][l] = 1

labels = oneHotLabels

testImages = xTest.reshape(len(xTest), 28*28) / 255
testLabels = np.zeros((len(yTest), 10))

for i,l in enumerate(yTest):
    testLabels[i][l] = 1

np.random.seed(1)

relu = lambda x: (x>=0) * x
relu2Deriv = lambda x: x>=0

alpha = 0.005
iterations = 300
hiddenSize = 100
pixelsPerImage = 784
numLabels = 10

weights1 = 0.2 * np.random.random((pixelsPerImage, hiddenSize)) - 0.1
weights2 = 0.2 * np.random.random((hiddenSize, numLabels)) - 0.1

for iter in range(iterations):
    trainingError, trainingCorrectCount = (0.0, 0)

    for i in range(len(images)):
        layer0 = images[i:i+1]
        layer1 = relu(np.dot(layer0, weights1))

        dropoutMask = np.random.randint(2, size=layer1.shape)
        layer1 *= dropoutMask * 2

        layer2 = np.dot(layer1, weights2)

        trainingError += np.sum((layer2 - labels[i:i+1]) ** 2)
        trainingCorrectCount += int(np.argmax(layer2) == np.argmax(labels[i:i+1]))

        delta2 = layer2 - labels[i:i+1]
        delta1 = delta2.dot(weights2.T) * relu2Deriv(layer1)

        delta1 *= dropoutMask

        weights2 -= alpha * layer1.T.dot(delta2)
        weights1 -= alpha * layer0.T.dot(delta1)
    
    if iter % 10 == 0 or iter == iterations-1:
        testError, testCorrectCount = (0.0, 0)

        for i in range(len(testImages)):
            layer0 = testImages[i:i+1]
            layer1 = relu(np.dot(layer0, weights1))
            layer2 = np.dot(layer1, weights2)

            testError += np.sum((layer2 - testLabels[i:i+1]) ** 2)
            testCorrectCount += int(np.argmax(layer2) == np.argmax(testLabels[i:i+1]))
        sys.stdout.write("Test-Error:" + str(testError/float(len(testImages)))[0:5] + " Test-KKR:" + str(testCorrectCount/float(len(testImages))))
        sys.stdout.write(" Training-Error:" + str(trainingError/float(len(images)))[0:5] + " Training-KKR:" + str(trainingCorrectCount/float(len(images))))
        print()
# Out:
# Test-Error:0.641 Test-KKR:0.6333 Training-Error:0.891 Training-KKR:0.413
# Test-Error:0.458 Test-KKR:0.787 Training-Error:0.472 Training-KKR:0.764
# Test-Error:0.415 Test-KKR:0.8133 Training-Error:0.430 Training-KKR:0.809
# Test-Error:0.421 Test-KKR:0.8114 Training-Error:0.415 Training-KKR:0.811
# Test-Error:0.419 Test-KKR:0.8112 Training-Error:0.413 Training-KKR:0.827
# Test-Error:0.409 Test-KKR:0.8133 Training-Error:0.392 Training-KKR:0.836
# Test-Error:0.412 Test-KKR:0.8236 Training-Error:0.402 Training-KKR:0.836
# Test-Error:0.412 Test-KKR:0.8033 Training-Error:0.383 Training-KKR:0.857
# Test-Error:0.410 Test-KKR:0.8054 Training-Error:0.386 Training-KKR:0.854
# Test-Error:0.411 Test-KKR:0.8144 Training-Error:0.376 Training-KKR:0.868
# Test-Error:0.411 Test-KKR:0.7903 Training-Error:0.369 Training-KKR:0.864
# Test-Error:0.411 Test-KKR:0.8003 Training-Error:0.371 Training-KKR:0.868
# Test-Error:0.402 Test-KKR:0.8046 Training-Error:0.353 Training-KKR:0.857
# Test-Error:0.408 Test-KKR:0.8091 Training-Error:0.352 Training-KKR:0.867
# Test-Error:0.405 Test-KKR:0.8083 Training-Error:0.355 Training-KKR:0.885
# Test-Error:0.404 Test-KKR:0.8107 Training-Error:0.342 Training-KKR:0.883
# Test-Error:0.399 Test-KKR:0.8146 Training-Error:0.361 Training-KKR:0.876
# Test-Error:0.404 Test-KKR:0.8074 Training-Error:0.344 Training-KKR:0.889
# Test-Error:0.399 Test-KKR:0.807 Training-Error:0.333 Training-KKR:0.892
# Test-Error:0.407 Test-KKR:0.8066 Training-Error:0.335 Training-KKR:0.898
# Test-Error:0.405 Test-KKR:0.8036 Training-Error:0.347 Training-KKR:0.893
# Test-Error:0.405 Test-KKR:0.8034 Training-Error:0.336 Training-KKR:0.894
# Test-Error:0.402 Test-KKR:0.8067 Training-Error:0.325 Training-KKR:0.896
# Test-Error:0.404 Test-KKR:0.8091 Training-Error:0.321 Training-KKR:0.894
# Test-Error:0.415 Test-KKR:0.8091 Training-Error:0.332 Training-KKR:0.898
# Test-Error:0.395 Test-KKR:0.8182 Training-Error:0.320 Training-KKR:0.899
# Test-Error:0.390 Test-KKR:0.8204 Training-Error:0.321 Training-KKR:0.899
# Test-Error:0.382 Test-KKR:0.8194 Training-Error:0.312 Training-KKR:0.906
# Test-Error:0.396 Test-KKR:0.8208 Training-Error:0.317 Training-KKR:0.9
# Test-Error:0.399 Test-KKR:0.8181 Training-Error:0.301 Training-KKR:0.908
# Test-Error:0.393 Test-KKR:0.8229 Training-Error:0.301 Training-KKR:0.916

# %%
# WITH RIGHT RELU FUNCTION => ITS WRONG ABOVE AND IN THE BOOK
import sys, numpy as np
from keras.datasets import mnist

(xTrain, yTrain), (xTest, yTest) = mnist.load_data()

images, labels = (xTrain[0:1000].reshape(1000, 28*28) / 255, yTrain[0:1000])

oneHotLabels = np.zeros((len(labels), 10))

for i,l in enumerate(labels):
    oneHotLabels[i][l] = 1

labels = oneHotLabels

testImages = xTest.reshape(len(xTest), 28*28) / 255
testLabels = np.zeros((len(yTest), 10))

for i,l in enumerate(yTest):
    testLabels[i][l] = 1

np.random.seed(1)

relu = lambda x: (x>0) * x
relu2Deriv = lambda x: x>0

alpha = 0.005
iterations = 300
hiddenSize = 100
pixelsPerImage = 784
numLabels = 10

weights1 = 0.2 * np.random.random((pixelsPerImage, hiddenSize)) - 0.1
weights2 = 0.2 * np.random.random((hiddenSize, numLabels)) - 0.1

for iter in range(iterations):
    trainingError, trainingCorrectCount = (0.0, 0)

    for i in range(len(images)):
        layer0 = images[i:i+1]
        layer1 = relu(np.dot(layer0, weights1))

        dropoutMask = np.random.randint(2, size=layer1.shape)
        layer1 *= dropoutMask * 2

        layer2 = np.dot(layer1, weights2)

        trainingError += np.sum((layer2 - labels[i:i+1]) ** 2)
        trainingCorrectCount += int(np.argmax(layer2) == np.argmax(labels[i:i+1]))

        delta2 = layer2 - labels[i:i+1]
        delta1 = delta2.dot(weights2.T) * relu2Deriv(layer1)

        delta1 *= dropoutMask

        weights2 -= alpha * layer1.T.dot(delta2)
        weights1 -= alpha * layer0.T.dot(delta1)
    
    if iter % 10 == 0 or iter == iterations-1:
        testError, testCorrectCount = (0.0, 0)

        for i in range(len(testImages)):
            layer0 = testImages[i:i+1]
            layer1 = relu(np.dot(layer0, weights1))
            layer2 = np.dot(layer1, weights2)

            testError += np.sum((layer2 - testLabels[i:i+1]) ** 2)
            testCorrectCount += int(np.argmax(layer2) == np.argmax(testLabels[i:i+1]))
        sys.stdout.write("Test-Error:" + str(testError/float(len(testImages)))[0:5] + " Test-KKR:" + str(testCorrectCount/float(len(testImages))))
        sys.stdout.write(" Training-Error:" + str(trainingError/float(len(images)))[0:5] + " Training-KKR:" + str(trainingCorrectCount/float(len(images))))
        print()
# Out:
# Test-Error:0.638 Test-KKR:0.6325 Training-Error:0.902 Training-KKR:0.395
# Test-Error:0.371 Test-KKR:0.8314 Training-Error:0.392 Training-KKR:0.819
# Test-Error:0.316 Test-KKR:0.8551 Training-Error:0.320 Training-KKR:0.884
# Test-Error:0.307 Test-KKR:0.8661 Training-Error:0.276 Training-KKR:0.918
# Test-Error:0.293 Test-KKR:0.8721 Training-Error:0.259 Training-KKR:0.931
# Test-Error:0.281 Test-KKR:0.8749 Training-Error:0.234 Training-KKR:0.94
# Test-Error:0.290 Test-KKR:0.8791 Training-Error:0.229 Training-KKR:0.957
# Test-Error:0.295 Test-KKR:0.8758 Training-Error:0.226 Training-KKR:0.958
# Test-Error:0.290 Test-KKR:0.8782 Training-Error:0.210 Training-KKR:0.961
# Test-Error:0.285 Test-KKR:0.8809 Training-Error:0.204 Training-KKR:0.95
# Test-Error:0.277 Test-KKR:0.8808 Training-Error:0.192 Training-KKR:0.97
# Test-Error:0.284 Test-KKR:0.8786 Training-Error:0.183 Training-KKR:0.975
# Test-Error:0.277 Test-KKR:0.8809 Training-Error:0.188 Training-KKR:0.97
# Test-Error:0.281 Test-KKR:0.8784 Training-Error:0.187 Training-KKR:0.963
# Test-Error:0.289 Test-KKR:0.8777 Training-Error:0.195 Training-KKR:0.969
# Test-Error:0.287 Test-KKR:0.8768 Training-Error:0.175 Training-KKR:0.973
# Test-Error:0.280 Test-KKR:0.8792 Training-Error:0.195 Training-KKR:0.968
# Test-Error:0.291 Test-KKR:0.876 Training-Error:0.174 Training-KKR:0.978
# Test-Error:0.289 Test-KKR:0.8762 Training-Error:0.183 Training-KKR:0.979
# Test-Error:0.287 Test-KKR:0.8746 Training-Error:0.174 Training-KKR:0.974
# Test-Error:0.286 Test-KKR:0.8766 Training-Error:0.168 Training-KKR:0.974
# Test-Error:0.288 Test-KKR:0.8756 Training-Error:0.177 Training-KKR:0.972
# Test-Error:0.288 Test-KKR:0.8761 Training-Error:0.166 Training-KKR:0.975
# Test-Error:0.291 Test-KKR:0.8754 Training-Error:0.160 Training-KKR:0.983
# Test-Error:0.290 Test-KKR:0.8735 Training-Error:0.167 Training-KKR:0.976
# Test-Error:0.291 Test-KKR:0.876 Training-Error:0.163 Training-KKR:0.978
# Test-Error:0.282 Test-KKR:0.8757 Training-Error:0.163 Training-KKR:0.976
# Test-Error:0.291 Test-KKR:0.8725 Training-Error:0.158 Training-KKR:0.984
# Test-Error:0.288 Test-KKR:0.8739 Training-Error:0.158 Training-KKR:0.979
# Test-Error:0.291 Test-KKR:0.8734 Training-Error:0.156 Training-KKR:0.985
# Test-Error:0.292 Test-KKR:0.8737 Training-Error:0.162 Training-KKR:0.983
